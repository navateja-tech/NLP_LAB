# %% [markdown]
# #### AIM 5 : Implement Tokenization and segmentation of the Text using Regular Expressions of NLTK

# %% [markdown]
# #### Tokenization is a foundational process of breaking down the raw text into smaller manageble words, it serves as a critical step in NLP because the machines cant understand the raw text ,so the text should be converted into tokens which are then converted into numerical identity numbers called embeddings

# %%
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import RegexpTokenizer
import re

url = "https://www.thehindu.com/news/national/"

response = requests.get(url)

# print(response.text)

soup = BeautifulSoup(response.text,'html.parser')

# print(soup)

text = " ".join(p.get_text() for p in soup.find_all('p'))

# print(text)

# docs = text.split(' ')

# tokens=[]
# for t in docs:
#     if t:
#         val = re.sub('[?\n\t\.\xa0]','',t)
#         tokens.append(val)

tokenizer = RegexpTokenizer(r'\w+')

tokens = tokenizer.tokenize(text)


print(tokens)
# Out:
# ['You', 'are', 'logged', 'in', 'Loading', 'You', 'don', 't', 'have', 'any', 'Active', 'Subscription', 'Subscribed', 'with', 'another', 'email', 'Logout', 'and', 'Login', 'with', 'that', 'one', 'Your', 'active', 'subscription', 's', 'Account', 'subscription', 'benefits', 'alongside', 'Premium', 'Stories', 'Editorials', 'Opinions', 'and', 'more', 'Unlock', 'these', 'with', 'Subscription', 'Products', 'you', 've', 'access', 'to', 'Additional', 'Subscription', 'Benefits', 'Account', 'Settings', 'Need', 'help', 'with', 'your', 'subscription', 'July', '23', '2026e', 'Paper', 'The', 'View', 'From', 'India', 'Looking', 'at', 'World', 'Affairs', 'from', 'the', 'Indian', 'perspective', 'First', 'Day', 'First', 'Show', 'News', 'and', 'reviews', 'from', 'the', 'world', 'of', 'cinema', 'and', 'streaming', 'Today', 's', 'Cache', 'Your', 'download', 'of', 'the', 'top', '5', 'technology', 'stories', 'of', 'the', 'day', 'Science', 'For', 'All', 'The', 'weekly', 'newsletter', 'from', 'science', 'writers', 'takes', 'the', 'jargon', 'out', 'of', 'science', 'and', 'puts', 'the', 'fun', 'in', 'Data', 'Point', 'Decoding', 'the', 'headlines', 'with', 'facts', 'figures', 'and', 'numbers', 'THEdge', 'At', 'the', 'cutting', 'edge', 'of', 'education', 'and', 'careers', 'Health', 'Matters', 'Ramya', 'Kannan', 'writes', 'to', 'you', 'on', 'getting', 'to', 'good', 'health', 'and', 'staying', 'there', 'Gender', 'Agenda', 'Stories', 'from', 'beyond', 'the', 'binary', 'The', 'Hindu', 'On', 'Books', 'Books', 'of', 'the', 'week', 'reviews', 'excerpts', 'new', 'titles', 'and', 'features', 'July', '23', '2026e', 'Paper', 'Copyright', '2026', 'THG', 'PUBLISHING', 'PVT', 'LTD', 'or', 'its', 'affiliated', 'companies', 'All', 'rights', 'reserved', 'BACK', 'TO', 'TOP', 'Terms', 'conditions', 'Institutional', 'Subscriber']
